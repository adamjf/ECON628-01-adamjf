# %% [markdown]
# <img src="https://images.efollett.com/htmlroot/images/templates/storeLogos/CA/864.gif" style="float: right;">
#
#
#
#
# # ECON628-01
# ### Late Midterm - In-class Exam
#
#
#
# ---
# #### Guidelines
# - This is your notebook for your in-class midterm exam.
# - You are required to submit your answers using this notebook (do not push or submit PDFs, Word docs, etc, if you do, your answers will be considered invalid = **0%**).
# - The in-class exam is **10%** of your total midterm score.
# - During the exam you can only have the following websites open in your browser:
#     * [ECON-628-01 github][1]
#     * ECON-628-01-yourgithubusersname
#     * [StackOverflow][2]
# - If we noticed that your computer browser has other websites open, you will be asked to **close your computer, leave the class, and will get an score of 0%**
# - Remember: if you are using code from someone else/online (StackOverflow) you need:
#     - Cite the website from where you are getting the code.
#     - **Explain on your "own words" what the code is doing.**
#     - If you fail to do this, your grade will be **penalized.**
#
#
#
# - Once you are done with your exam use this [link][3] to **submit** the GitHub link to your take home exam.
# [1]:https://github.com/jrcmalunay/ECON628-01 "ECON-628-01 github"
# [2]:http://stackoverflow.com "StackOverflow"
# [3]: https://docs.google.com/forms/d/e/1FAIpQLSercXrXIky91taz98tPviIqA8C0FaQZ_WIfNoRYxMbV5wPtkg/viewform "link"
#
# - **Finally: YOU HAVE 1:15 MIN TO COMPLETE THIS EXAM**
#
# ---

# %% [markdown]
# ## 1. Cartesian Product (Python Code Academy)
# ---
# Exercise:
# Create a Cartesian product of t-shirt colors/sizes using a list comprehension.
# Where Cartesian product = the product of two sets: the product of set X and set Y is the set that contains all ordered pairs ( x, y ) for which x belongs to X and y belongs to Y.
#
#     Inputs:
#     colors = ['black', 'white']
#     sizes = ['S', 'M', 'L']
#
#     Output:
#     [('black', 'S'), ('black', 'M'), ('black', 'L'),
#      ('white', 'S'), ('white', 'M'), ('white', 'L')]
#
# ---

# %%
colors = ['black', 'white']
sizes = ['S', 'M', 'L']

output = [x for x in colors, y for y in sizes]
print output
# Out:
# [['black', 'white'], ['black', 'white'], ['black', 'white'], 'L', 'L', 'L']

# %%
out = [x for xs in colors for x in sizes]
print out
# Out:
# ['S', 'M', 'L', 'S', 'M', 'L']

# %%
for x, y in zip(colors, sizes):
    print x, y
# Out:
# black S
# white M

# %%
outp = [x for x in colors for y in sizes]
print outp
# Out:
# ['e', 'e', 'e']

# %%
for a,b in zip(colors,sizes):
     print(a,b)
# Out:
# ('e', 'S')

# %%
sizes = pd.dataframe(sizes)
colors = pd.dataframe(colors)

op = sizes.crossJoin(colors)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-c759dcc8fbad> in <module>()
# ----> 1 sizes = pd.dataframe(sizes)
#       2 colors = pd.dataframe(colors)
#       3
#       4 op = sizes.crossJoin(colors)
#
# AttributeError: 'module' object has no attribute 'dataframe'

# %% [markdown]
# ## 2. Sorting a list (Python Code Academy)
# ---
# Exercise:
# Given the following list
#
#     fruits = ['strawberry','fig','apple','cherry','raspberry','banana']
#
# Sort the list by the lenght of its elements
#
#     Output should be:
#     ['fig', 'apple', 'cherry', 'banana', 'raspberry', 'strawberry']
#
# ---

# %%
fruits = ['strawberry','fig','apple','cherry','raspberry','banana']
for x in fruits:
    print len(x)
# Out:
# 10
# 3
# 5
# 6
# 9
# 6

# %%
fruits.sort(key = len)
print fruits
# Out:
# ['fig', 'apple', 'cherry', 'banana', 'raspberry', 'strawberry']

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')

# %% [markdown]
# ## 3. Read/load the dataset "sleep_bh.csv" and do an initial overview of the data
#     print the number of columns in the data
#     check the type of values in your data
#     create a dataframe with the variables that have missing values
#     print a list of the indices where there are missing values
# ---

# %%
'''read data set'''
sleep_path = 'C:/Users/Adam/Desktop/ECON628-01-adamjf/datasets/sleep/sleep_bh.csv'
sleep = pd.read_csv(sleep_path)

'''number of columns'''
len(sleep.columns)
# 34 columns
# Out:
# 34

# %%
'''Type of value in the dataset'''
sleep.info()


# data types are as follows: integers and floats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 34 columns):
# age         706 non-null int64
# black       706 non-null int64
# case        706 non-null int64
# clerical    706 non-null float64
# construc    706 non-null float64
# educ        706 non-null int64
# earns74     706 non-null int64
# gdhlth      706 non-null int64
# inlf        706 non-null int64
# leis1       706 non-null int64
# leis2       706 non-null int64
# leis3       706 non-null int64
# smsa        706 non-null int64
# lhrwage     532 non-null float64
# lothinc     706 non-null float64
# male        706 non-null int64
# marr        706 non-null int64
# prot        706 non-null int64
# rlxall      706 non-null int64
# selfe       706 non-null int64
# sleep       706 non-null int64
# slpnaps     706 non-null int64
# south       706 non-null int64
# spsepay     706 non-null int64
# spwrk75     706 non-null int64
# totwrk      706 non-null int64
# ...

# %%
'''Dataframe Variables and missing values'''
sleep.isnull().sum()

# variables are listed; 174 each missing from lhrwage and hrwage
# Out:
# age           0
# black         0
# case          0
# clerical      0
# construc      0
# educ          0
# earns74       0
# gdhlth        0
# inlf          0
# leis1         0
# leis2         0
# leis3         0
# smsa          0
# lhrwage     174
# lothinc       0
# male          0
# marr          0
# prot          0
# rlxall        0
# selfe         0
# sleep         0
# slpnaps       0
# south         0
# spsepay       0
# spwrk75       0
# totwrk        0
# union         0
# worknrm       0
# workscnd      0
# exper         0
# yngkid        0
# yrsmarr       0
# hrwage      174
# agesq         0
# dtype: int64

# %%
missing = sleep[["lhrwage", "hrwage"]]

# new sub-df 'missing' is a df of just these two columns with missing values

# %%
'''List of indices where there are missing values'''

sleep.lhrwage[sleep.lhrwage != sleep.lhrwage].index.values

# indices of missing values of lhrwage
# Out:
# array([532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544,
#        545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557,
#        558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570,
#        571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583,
#        584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596,
#        597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609,
#        610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622,
#        623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635,
#        636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648,
#        649, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661,
#        662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674,
#        675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687,
#        688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700,
# ...

# %%
sleep.hrwage[sleep.hrwage != sleep.hrwage].index.values

# indices of missing values of hrwage
# Out:
# array([532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544,
#        545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557,
#        558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570,
#        571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583,
#        584, 585, 586, 587, 588, 589, 590, 591, 592, 593, 594, 595, 596,
#        597, 598, 599, 600, 601, 602, 603, 604, 605, 606, 607, 608, 609,
#        610, 611, 612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622,
#        623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635,
#        636, 637, 638, 639, 640, 641, 642, 643, 644, 645, 646, 647, 648,
#        649, 650, 651, 652, 653, 654, 655, 656, 657, 658, 659, 660, 661,
#        662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672, 673, 674,
#        675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687,
#        688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700,
# ...

# %% [markdown]
# ## 4. Drop missing values (not the best practice), but OK for exam
#     Once you drop the missing values, check that the list of binary variables have values of 1 an 0
#         Note: at this point the inlf predictor/variable should have the value of 1
# ---

# %%
'''Drop missing values'''

sleep.dropna(axis=0, inplace=True)

sleep.shape

# drop rows with missing values
# 706-174 = 532 : check!
# Out:
# (532, 34)

# %%
'''Check Binary Entries'''

vars = list(sleep)
for x in vars:
    print x, sleep[x].nunique()
    
# creating 'vars', a list of the variables in the df sleep
# using a for-loop to print a list of the variable with corresponding unique value counts. My only way to know which variables
# are binary is to count the number of values. If the number is way over 2, I assume it's intended as such. If it's one or
# three...maybe not.
# clerical and construc both have 3 unique values, everything else has at least 19.
# Out:
# age 43
# black 2
# case 532
# clerical 2
# construc 2
# educ 15
# earns74 19
# gdhlth 2
# inlf 1
# leis1 472
# leis2 459
# leis3 461
# smsa 2
# lhrwage 252
# lothinc 66
# male 2
# marr 2
# prot 2
# rlxall 416
# selfe 2
# sleep 366
# slpnaps 404
# south 2
# spsepay 98
# spwrk75 2
# totwrk 388
# union 2
# worknrm 379
# workscnd 31
# exper 51
# yngkid 2
# yrsmarr 43
# hrwage 252
# agesq 43

# %%
vars = list(sleep)
for x in vars:
    if sleep[x].nunique() <= 3:
        print x, sleep[x].nunique()

        
# looking at the subset of the list in which we are interested: let's investigate clerical and construc

print sleep['clerical'].unique()
print sleep['construc'].unique()

# each has 0/1 values and a strange decimal value...let's drop those rows with decimal values:

sleep = sleep[(sleep.clerical == 0) | (sleep.clerical == 1) ]
sleep = sleep[(sleep.construc == 0) | (sleep.construc == 1) ]

# inlf just has one values; it isn't binary
# Out:
# black 2
# clerical 2
# construc 2
# gdhlth 2
# inlf 1
# smsa 2
# male 2
# marr 2
# prot 2
# selfe 2
# south 2
# spwrk75 2
# union 2
# yngkid 2
# [ 0.  1.]
# [ 0.  1.]

# %%
sleep.black.value_counts()
# Out:
# 0    505
# 1     27
# Name: black, dtype: int64

# %%
sleep.clerical.value_counts()
# Out:
# 0.0    435
# 1.0     97
# Name: clerical, dtype: int64

# %%
sleep.construc.value_counts()
# Out:
# 0.0    516
# 1.0     16
# Name: construc, dtype: int64

# %%
sleep.gdhlth.value_counts()
# Out:
# 1    471
# 0     61
# Name: gdhlth, dtype: int64

# %%
sleep.smsa.value_counts()
# Out:
# 0    323
# 1    209
# Name: smsa, dtype: int64

# %%
sleep.male.value_counts()
# Out:
# 1    293
# 0    239
# Name: male, dtype: int64

# %%
sleep.marr.value_counts()
# Out:
# 1    435
# 0     97
# Name: marr, dtype: int64

# %%
sleep.prot.value_counts()
# Out:
# 1    361
# 0    171
# Name: prot, dtype: int64

# %%
sleep.south.value_counts()
# Out:
# 0    422
# 1    110
# Name: south, dtype: int64

# %%
sleep.spwrk75.value_counts()
# Out:
# 1    279
# 0    253
# Name: spwrk75, dtype: int64

# %%
sleep.union.value_counts()
# Out:
# 0    415
# 1    117
# Name: union, dtype: int64

# %%
sleep.yngkid.value_counts()
# Out:
# 0    457
# 1     75
# Name: yngkid, dtype: int64

# %%
sleep.shape
# Out:
# (532, 34)

# %%
# check! all binary variables have 0/1 values

# %% [markdown]
# ## 5. Implement a correlation heatmap and suggest models (don't implement the models)
# ---

# %%
'''Correlation Heatmap'''
fig = plt.figure(figsize=(18,10))
ax = fig.gca()
sns.heatmap(sleep.corr(), annot=True, linewidths=.15, cmap="YlGnBu", vmin=0, vmax=1, ax=ax)
plt.show()

# %%
'''Models'''

# With primary outcome of interest: hours of sleep, we can try to predict this outcome using the data we have. For variables
# with continuous domains we can use OLS, WLS, lasso regression, or ridge regression. For variables that take binary values we 
# may use logit, probit, or ML classification models like forest, random forest. We may also use 2-part methods if we believe
# that the data generating process is a two-step one such as heckman 2-step regression.
