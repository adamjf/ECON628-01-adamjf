# %%
# ADAM FRANKLIN
# ECON 628
# PROJECT 2

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')

# %%
stops_path = 'C:/Users/Adam/Desktop/ECON628-01-adamjf/datasets/Officer_Traffic_Stops.csv'
stops = pd.read_csv(stops_path)

# %%
stops.head()
# Out:
#   month_of_stop            reason_for_stop            officer_race  \
# 0       2016/01  Speeding                                    White
# 1       2016/01  Stop Light/Sign                             White
# 2       2016/01  Speeding                                    White
# 3       2016/01  Vehicle Regulatory         Black/African American
# 4       2016/01  Vehicle Regulatory                          White
#
#   officer_gender  officer_years_of_service driver_race driver_ethnicity  \
# 0           Male                         6       White     Non-Hispanic
# 1           Male                         6       Black     Non-Hispanic
# 2           Male                         6       Black     Non-Hispanic
# 3           Male                         2       Black     Non-Hispanic
# 4           Male                         6       White     Non-Hispanic
#
#   driver_gender  driver_age was_a_search_conducted   result_of_stop  \
# 0          Male          63                     No  Citation Issued
# 1          Male          35                     No   Verbal Warning
# 2          Male          30                     No  Citation Issued
# 3        Female          29                     No   Verbal Warning
# 4          Male          45                     No  Citation Issued
#
#       cmpd_division  objectid              creationdate        creator  \
# 0  Eastway Division      1001  2016-12-20T23:49:30.533Z  charlottedata
# 1  Eastway Division      1002  2016-12-20T23:49:30.533Z  charlottedata
# 2  Eastway Division      1003  2016-12-20T23:49:30.533Z  charlottedata
# 3    Metro Division      1004  2016-12-20T23:49:30.533Z  charlottedata
# 4  Eastway Division      1005  2016-12-20T23:49:30.533Z  charlottedata
#
#                    editdate         editor
# 0  2016-12-20T23:49:30.533Z  charlottedata
# 1  2016-12-20T23:49:30.533Z  charlottedata
# 2  2016-12-20T23:49:30.533Z  charlottedata
# 3  2016-12-20T23:49:30.533Z  charlottedata
# 4  2016-12-20T23:49:30.533Z  charlottedata

# %%
stops.officer_race.value_counts()
# Out:
# White                             57722
# Black/African American            13886
# Asian / Pacific Islander           4349
# Hispanic/Latino                    2886
# Not Specified                       460
#                                     261
# American Indian/Alaska Native       241
# Native Hawaiian/Oth Pac Island       79
# Name: officer_race, dtype: int64

# %%
stops.driver_race.value_counts()
# Out:
# Black              42970
# White              32969
# Other/Unknown       2422
# Asian               1461
# Native American       62
# Name: driver_race, dtype: int64

# %%
stops.driver_ethnicity.value_counts()
# Out:
# Non-Hispanic    72306
# Hispanic         7578
# Name: driver_ethnicity, dtype: int64

# %%
def histogram_plotter(title, data):
    sns.set(rc={"figure.figsize": (10, 7)})
    sns.set_style('white')
    dist = sns.distplot(data, hist_kws={'alpha':0.2}, kde_kws={'linewidth':2})
    
    dist.axvline(np.mean(data), lw=1, c='darkred', ls='dashed')
    average_roll = '{0:.2f}'.format(np.mean(data))
    title = 'Distribution of ' + title + '; average = '  + average_roll + '\n'
    dist.set_title(title, fontsize=16)
    dist = sns.distplot(data, hist_kws={'alpha':0.2}, kde_kws={'linewidth':2})

# %%
stops.isnull().sum()
# Out:
# month_of_stop                  0
# reason_for_stop                0
# officer_race                   0
# officer_gender                 0
# officer_years_of_service       0
# driver_race                    0
# driver_ethnicity               0
# driver_gender                  0
# driver_age                     0
# was_a_search_conducted         0
# result_of_stop                 0
# cmpd_division               9586
# objectid                       0
# creationdate                   0
# creator                        0
# editdate                       0
# editor                         0
# dtype: int64

# %%
driver_age = stops.driver_age
officer_years_of_service = stops.officer_years_of_service
histogram_plotter("Driver Age", officer_years_of_service)

# %%
stops.reason_for_stop.value_counts()
# Out:
# Vehicle Regulatory           32405
# Speeding                     22222
# Stop Light/Sign               7946
# Vehicle Movement              7535
# Safe Movement                 4827
# Investigation                 1992
# Other                         1926
# SeatBelt                       631
# CheckPoint                     286
# Driving While Impaired         114
# Name: reason_for_stop, dtype: int64
